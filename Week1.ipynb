# %% [markdown]
# <a href="https://colab.research.google.com/github/bintangsholu21/PCVK/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **MODUL 1 – Penggunaan Github dan Google Colaboratory, Membaca dan Menampilkan Citra**

# %% [markdown]
# **Pengolahan Citra dan Visi Komputer – Jurusan Teknologi Informasi**
#
# ---

# %% [markdown]
# Nama      : Muhammad Bintang Sholu Firmansyah
#
# Kelas     : TI-3G
#
# No Absen  : 16
#
# NIM       : 2141720101
#
# ***

# %% [markdown]
# Langkah (Step) 1 :

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# Langkah (Step) 2 :

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pad alist
for url in urls:
  image = io.imread(url)                            #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)   #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)    #convert color to RGB
  final_frame = cv.hconcat((image, image_2))        #concatenate image
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# Langkah (Step) 3 :
#
# *Melihat ukuran File Image*

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  286  x  400
# <PIL.Image.Image image mode=RGB size=400x286>

# %% [markdown]
# Langkah (Step) 4
#
# *mengakses pixel dengan memberi garis diagonal menyilang*

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255, 255, 255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ### Pertanyaan

# %% [markdown]
# **1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?**
#
# Jawab :
#
# Google Colab adalah platform cloud gratis berbasis Jupyter Notebook yang mendukung bahasa pemrograman Python dan menyediakan akses ke GPU secara gratis. Dengan fitur kolaborasi tim, integrasi dengan Google Drive, dan dukungan untuk banyak pustaka Python, Colab mempermudah penulisan, eksekusi, dan berbagi kode program tanpa perlu instalasi lokal, menjadikannya alat yang kuat untuk pengembangan AI dan eksplorasi data.

# %% [markdown]
# **2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?**
#
# Jawab :
#
#
# - `numpy`: Ini adalah sebuah pustaka yang digunakan untuk manipulasi array, operasi aljabar linear, transformasi Fourier, dan juga untuk menghasilkan angka acak.
#
# - `Pandas`: Pandas adalah pustaka yang digunakan untuk manipulasi dan analisis data. Ini menyediakan struktur data tingkat tinggi seperti DataFrame, yang berguna untuk memanipulasi data tabular.
#
# - `cv2` (OpenCV): OpenCV adalah pustaka komputer vision yang kuat. Digunakan untuk tugas pengolahan gambar dan komputer, seperti membaca, menulis, dan memproses gambar.
#
# - `Skimage`: Skimage adalah pustaka yang mendukung aplikasi pengolahan gambar dalam bahasa pemrograman Python. Ini berguna untuk berbagai tugas pemrosesan gambar.
#
# - `matplotlib`: Matplotlib adalah pustaka yang digunakan untuk membuat visualisasi data, termasuk pembuatan grafik dan plot. Ini juga menyediakan toolkit antarmuka pengguna grafis.
#
# - `google.colab.patches.cv2_imshow`: Digunakan untuk menampilkan gambar dalam lingkungan Google Colab.

# %% [markdown]
# **3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :**
#
# `image = cv.resize(image, (0,0), fx=0.5, fy=0.5)`
#
# **Apa kegunaan kode program tersebut?dan apa pengaruhnya jika tidak dilakukan?**
#
# Jawab :
#
# Kode `image = cv.resize(image, (0,0), fx=0.5, fy=0.5)` digunakan untuk mengubah ukuran gambar, secara khusus, menguranginya menjadi setengah dari ukuran aslinya baik secara horizontal maupun vertikal. Ini membantu menghemat penggunaan memori dan memungkinkan pengolahan lebih efisien pada gambar yang lebih besar. Tanpa kode ini, gambar akan tetap dalam ukuran aslinya, yang bisa mengonsumsi lebih banyak sumber daya komputasi.

# %% [markdown]
# **4. Perhatikan potongan kode progam berikut :**
# ```
# #membuat garis horizontal ditengah image
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255, 255, 255]
# ```
# **Apakah kegunaan kode [255,255,255] ? Jelaskan!**
#
# Jawab :
#
# Kode `[255, 255, 255]` digunakan untuk merepresentasikan warna putih dalam format RGB. Setiap komponen (merah, hijau, dan biru) memiliki nilai maksimum 255 dalam format ini, sehingga `[255, 255, 255]` adalah representasi warna putih yang lengkap. Ketika kode ini diterapkan pada pixel dalam gambar, ia mengganti warna pixel tersebut menjadi warna putih penuh (tidak ada warna) yang biasanya digunakan untuk menggambar atau menghapus detail tertentu pada gambar.

# %% [markdown]
# **5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!**
#
# Jawab :
#
# Resolusi gambar adalah jumlah piksel dalam gambar. Semakin tinggi resolusinya, semakin banyak detail yang dapat direpresentasikan, dan ini dihitung dengan mengalikan tinggi dan lebar gambar dengan jumlah piksel per unit panjangnya. Resolusi tinggi cocok untuk gambar dengan detail halus, sementara resolusi rendah cocok untuk gambar kasar dengan ukuran file lebih kecil.

# %% [markdown]
# **TUGAS**

# %% [markdown]
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

# membuat garis diagonal menyilang
for y in range (tinggi):
  image_4[y,int(y*(lebar/tinggi))] = [255,255,255]
  image_4[y,lebar-1-int(y*(lebar/tinggi))] = [255,255,255]

final_frame1 = cv.hconcat((image_2, image_3))
final_frame2 = cv.hconcat((image_2, image_4))
print('Garis Vertikal Ditengah Image')
cv2_imshow(final_frame1)
print('\n')
print('Garis Diagonal Menyilang ')
cv2_imshow(final_frame2)
# Out:
# Garis Vertikal Ditengah Image
# <PIL.Image.Image image mode=RGB size=800x286>
# Garis Diagonal Menyilang
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang tertentu

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal ditengah image
for x in range ((tinggi - 100)//2, (tinggi - 100)//2 + 100 ):
  image_3[int((tinggi)/2), x] = [255,255,255]


final_frame = cv.hconcat((image_2, image_3))
print('Garis Horizontal ditengah dengan panjang tertentu ')
cv2_imshow(final_frame)
# Out:
# Garis Horizontal ditengah dengan panjang tertentu
# <PIL.Image.Image image mode=RGB size=800x286>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat kotak menggunakan kumpulan pixel warna putih
for x in range ((tinggi - 100)//2, (tinggi - 100)//2 + 100 ):
  for y in range((lebar - 100) //2, (lebar - 100) // 2 + 100):
    image_3[x+7,y-50] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
print('Kotak menggunakan kumpulan pixel warna putih')
cv2_imshow(final_frame)
# Out:
# Kotak menggunakan kumpulan pixel warna putih
# <PIL.Image.Image image mode=RGB size=800x286>

# %% [markdown]
# ---
# ## **Tugas Kelompok**
#
# Kelompok 6 tutup Pekerjaan dan kewarganegaraan
#
# 1. Clarita Putri Anggraeni  (07)
# 2. Muhammad Bintang Sholu Firmansyah (16)
# 3. Muhammad Ilzam Mulkhaq (17)

# %% [markdown]
# Soal
#
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib

# %%
image_path = '/content/drive/MyDrive/PCVK/sample/KTP.jpeg'

# Baca gambar menggunakan OpenCV
image = cv.imread(image_path)

# Konversi format warna dari BGR (OpenCV) ke RGB (Matplotlib)
image_rgb = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Tampilkan gambar menggunakan Matplotlib
plt.imshow(image_rgb)
# plt.axis('off')  # Matplotlib tidak menampilkan sumbu
plt.show()

# %% [markdown]
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
#
#
#
# > *OpenCV menggunakan format BGR (Blue-Green-Red) sebagai default, sedangkan Matplotlib menggunakan format RGB (Red-Green-Blue). Oleh karena itu, perlu mengonversi format warna dari BGR ke RGB untuk tampilan yang benar.*
#
#
#
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 6 tutup Pekerjaan dan kewarganegaraan

# %%
import cv2
import matplotlib.pyplot as plt

# Ganti dengan path gambar Anda
image_path = '/content/drive/MyDrive/PCVK/sample/KTP.jpeg'

# Baca gambar menggunakan OpenCV
image = cv2.imread(image_path)

# Membuat salinan gambar untuk dimodifikasi
image_copy = image.copy()

# Menentukan koordinat dan ukuran kotak pekerjaan
x_box = 194
y_box = 326
width_box = 285
height_box = 22

# Loop untuk menggambar kotak pekerjaan pada gambar
image_with_box = image_rgb
for y in range(y_box, y_box + height_box):
    for x in range(x_box, x_box + width_box):
        image_copy[y, x] = [0, 255, 0]

# Menentukan koordinat dan ukuran kotak Kewarganegaraan
x_box = 194
y_box = 350
width_box = 50
height_box = 22

# Loop untuk menggambar kotak Kewarganegaraa pada gambar
image_with_box = image_rgb
for y in range(y_box, y_box + height_box):
    for x in range(x_box, x_box + width_box):
        image_copy[y, x] = [255, 0, 0]

# Konversi format warna dari BGR (OpenCV) ke RGB (Matplotlib)
image_rgb = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

# Tampilkan gambar dengan kotak menggunakan
plt.imshow(image_rgb)
plt.show()
